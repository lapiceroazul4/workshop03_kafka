# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import joblib

# %%
df_2015 = pd.read_csv('..\data\df_2015.csv')
df_2015.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
columnas = {
"Happiness Rank":"happiness_rank",
"Country":"country",
"Happiness Score":"happiness_score",
"Economy (GDP per Capita)":"GDP_per_capita",
"Health (Life Expectancy)":"life_expectancy",
"Freedom":"freedom",
"Trust (Government Corruption)":"perceptions_corruption",
"Generosity":"generosity"
}
df_2015.rename(columns=columnas, inplace = True)
df_2015 = df_2015[["country", "happiness_rank", "happiness_score", "GDP_per_capita", "life_expectancy", 
                   "freedom", "perceptions_corruption", "generosity"]]
df_2015.columns
# Out:
# Index(['country', 'happiness_rank', 'happiness_score', 'GDP_per_capita',
#        'life_expectancy', 'freedom', 'perceptions_corruption', 'generosity'],
#       dtype='object')

# %%
df_2016 = pd.read_csv('..\data\df_2016.csv')

# %%
columnas = {
"Happiness Rank":"happiness_rank",
"Country":"country",
"Happiness Score":"happiness_score",
"Economy (GDP per Capita)":"GDP_per_capita",
"Health (Life Expectancy)":"life_expectancy",
"Freedom":"freedom",
"Trust (Government Corruption)":"perceptions_corruption",
"Generosity":"generosity"
}
df_2016.rename(columns=columnas, inplace = True)
df_2016 = df_2016[["country", "happiness_rank", "happiness_score", "GDP_per_capita", "life_expectancy", 
                   "freedom", "perceptions_corruption", "generosity"]]
df_2016.columns
# Out:
# Index(['country', 'happiness_rank', 'happiness_score', 'GDP_per_capita',
#        'life_expectancy', 'freedom', 'perceptions_corruption', 'generosity'],
#       dtype='object')

# %%
df_2017 = pd.read_csv('../data/df_2017.csv')
df_2017.head(2)
# Out:
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707

# %%
columnas = {
"Happiness.Rank":"happiness_rank",
"Country":"country",
"Happiness.Score":"happiness_score",
"Economy..GDP.per.Capita.":"GDP_per_capita",
"Health..Life.Expectancy.":"life_expectancy",
"Trust..Government.Corruption.":"perceptions_corruption",
"Freedom":"freedom",
"Generosity":"generosity"
}
df_2017.rename(columns=columnas, inplace = True)
df_2017 = df_2017[["country", "happiness_rank", "happiness_score", "GDP_per_capita", "life_expectancy", 
                   "freedom", "perceptions_corruption", "generosity"]]
df_2017.columns
# Out:
# Index(['country', 'happiness_rank', 'happiness_score', 'GDP_per_capita',
#        'life_expectancy', 'freedom', 'perceptions_corruption', 'generosity'],
#       dtype='object')

# %%
df_2018 = pd.read_csv('../data/df_2018.csv')
df_2018.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340

# %%
columnas = {
"Overall rank":"happiness_rank",
"Country or region":"country",
"Score":"happiness_score",
"GDP per capita":"GDP_per_capita",
"Healthy life expectancy":"life_expectancy",
"Freedom to make life choices":"freedom",
"Perceptions of corruption":"perceptions_corruption",
"Generosity":"generosity"
}
df_2018.rename(columns=columnas, inplace = True)
df_2018 = df_2018[["country", "happiness_rank", "happiness_score", "GDP_per_capita", "life_expectancy", 
                   "freedom", "perceptions_corruption", "generosity"]]
df_2018.columns
# Out:
# Index(['country', 'happiness_rank', 'happiness_score', 'GDP_per_capita',
#        'life_expectancy', 'freedom', 'perceptions_corruption', 'generosity'],
#       dtype='object')

# %%
df_2019 = pd.read_csv('../data/df_2019.csv')
df_2019.head(2)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410

# %%
df_2019.drop(["Social support"], axis="columns", inplace=True)
columnas = {
"Overall rank":"happiness_rank",
"Country or region":"country",
"Score":"happiness_score",
"GDP per capita":"GDP_per_capita",
"Healthy life expectancy":"life_expectancy",
"Freedom to make life choices":"freedom",
"Perceptions of corruption":"perceptions_corruption",
"Generosity":"generosity"
}
df_2019.rename(columns=columnas, inplace = True)
df_2019 = df_2019[["country", "happiness_rank", "happiness_score", "GDP_per_capita", "life_expectancy", 
                   "freedom", "perceptions_corruption", "generosity"]]
df_2018.columns
# Out:
# Index(['country', 'happiness_rank', 'happiness_score', 'GDP_per_capita',
#        'life_expectancy', 'freedom', 'perceptions_corruption', 'generosity'],
#       dtype='object')

# %% [markdown]
# ##### Merge

# %%
df = pd.concat([df_2016,df_2017,df_2018,df_2019])
df.columns
# Out:
# Index(['country', 'happiness_rank', 'happiness_score', 'GDP_per_capita',
#        'life_expectancy', 'freedom', 'perceptions_corruption', 'generosity'],
#       dtype='object')

# %%
df.dtypes
# Out:
# country                    object
# happiness_rank              int64
# happiness_score           float64
# GDP_per_capita            float64
# life_expectancy           float64
# freedom                   float64
# perceptions_corruption    float64
# generosity                float64
# dtype: object

# %%
df.shape
# Out:
# (624, 8)

# %%
duplicados_por_columna = df.duplicated()
duplicados_por_columna.sum()
# Out:
# 0

# %%
(
    df
    .isnull()
    .sum()
    .sort_values(ascending=False)
)
# Out:
# perceptions_corruption    1
# country                   0
# happiness_rank            0
# happiness_score           0
# GDP_per_capita            0
# life_expectancy           0
# freedom                   0
# generosity                0
# dtype: int64

# %%
df.describe()
# Out:
#        happiness_rank  happiness_score  GDP_per_capita  life_expectancy  \
# count      624.000000       624.000000      624.000000       624.000000
# mean        78.496795         5.379849        0.933749         0.607897
# std         45.071229         1.123896        0.406818         0.248613
# min          1.000000         2.693000        0.000000         0.000000
# 25%         39.750000         4.495250        0.635073         0.440765
# 50%         78.500000         5.337500        0.993275         0.640590
# 75%        117.250000         6.184500        1.254088         0.808000
# max        157.000000         7.769000        2.096000         1.141000
#
#           freedom  perceptions_corruption  generosity
# count  624.000000              623.000000  624.000000
# mean     0.406654                0.120874    0.213836
# std      0.153231                0.101497    0.120835
# min      0.000000                0.000000    0.000000
# 25%      0.306210                0.053000    0.127045
# 50%      0.430694                0.089000    0.199985
# 75%      0.525250                0.150500    0.271005
# max      0.724000                0.505210    0.838075

# %%
#Fill N/A value with the Mean
df["perceptions_corruption"].fillna(0.120874, inplace=True)
(
    df
    .isnull()
    .sum()
    .sort_values(ascending=False)
)
# Out:
# country                   0
# happiness_rank            0
# happiness_score           0
# GDP_per_capita            0
# life_expectancy           0
# freedom                   0
# perceptions_corruption    0
# generosity                0
# dtype: int64

# %%
data = df.drop("country", axis=1)
# Calcular la matriz de correlación
correlation_matrix = data.corr()

# Crear un gráfico de correlación con heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Unir el conjunto de datos geoespaciales con los datos de felicidad
world = world.merge(df, left_on='name', right_on='country', how='left')

# Crear el mapa de calor
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
world.boundary.plot(ax=ax, linewidth=1)
world.plot(column='happiness_score', cmap='coolwarm', ax=ax, legend=True)

# Configurar la leyenda
ax.set_title('Happiness Score by Country')
ax.set_axis_off()

plt.show()
# Out:
# C:\Users\SANTIAGO\AppData\Local\Temp\ipykernel_70956\2766606030.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
data1 = df[["GDP_per_capita", 
        "life_expectancy", "freedom", "perceptions_corruption", 
        "generosity", "happiness_score"]]
data1.to_csv("data_result.csv", index=False)

# %% [markdown]
# ##### Regression Model

# %%
# Definir características (X) y variable objetivo (y)
X = df[["GDP_per_capita", 
        "life_expectancy", "freedom", "perceptions_corruption", 
        "generosity"]]

y = df["happiness_score"]

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Crear el modelo de regresión lineal
model = LinearRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = model.predict(X_test)

# Evaluar el modelo
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

model_filename = "modelo_regresion.pkl"
joblib.dump(model, model_filename)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Squared Error: 0.29539966169573756
# R-squared: 0.7572799291050193
# Mean Absolute Error (MAE): 0.41955570455010427
